# %%
# !gdown 1ujSYC3tEC3VNoxqUIWO2PG7Lg5HAdYqn
# !tar -xf models.zip
# Out:
# Downloading...
# From (uriginal): https://drive.google.com/uc?id=1ujSYC3tEC3VNoxqUIWO2PG7Lg5HAdYqn
# From (redirected): https://drive.google.com/uc?id=1ujSYC3tEC3VNoxqUIWO2PG7Lg5HAdYqn&confirm=t&uuid=6c875881-8e5b-4d9c-8ec3-dfed62c8294a
# To: f:\Projects\bengali-lpr\models.zip
#
#   0%|          | 0.00/305M [00:00<?, ?B/s]
#   0%|          | 524k/305M [00:00<03:44, 1.35MB/s]
#   1%|          | 1.57M/305M [00:00<01:22, 3.69MB/s]
#   1%|          | 2.62M/305M [00:00<01:09, 4.35MB/s]
#   1%|▏         | 4.19M/305M [00:00<00:43, 6.83MB/s]
#   2%|▏         | 5.24M/305M [00:00<00:41, 7.29MB/s]
#   2%|▏         | 6.29M/305M [00:01<00:38, 7.65MB/s]
#   2%|▏         | 7.34M/305M [00:01<00:37, 7.88MB/s]
#   3%|▎         | 8.39M/305M [00:01<00:36, 8.05MB/s]
#   3%|▎         | 9.44M/305M [00:01<00:36, 8.18MB/s]
#   3%|▎         | 10.5M/305M [00:01<00:35, 8.29MB/s]
#   4%|▍         | 11.5M/305M [00:01<00:35, 8.34MB/s]
#   4%|▍         | 12.6M/305M [00:01<00:34, 8.39MB/s]
# ...

# %%
import utils
utils.show_image('images/test_image.jpg')

# %%
utils.detect_and_extract_lp_text('images/test_image.jpg')
# Out:
# ('ঢাকা মেট্রো-গ', '১৯-০৪৭৬')
# ('ঢাকা মেট্রো-গ', '১৯-০৪৭৬')

# %%
utils.show_image('images/My_car_image.jpg')

# %%
utils.detect_and_extract_lp_text('images/My_car_image.jpg')
# Out:
# ('রাজ মেট্রো-ঢ', '১৮-১৫৭১')
# ('রাজ মেট্রো-ঢ', '১৮-১৫৭১')
